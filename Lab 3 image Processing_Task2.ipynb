# %%
#Ahmed Ali Alyousif/8MA02/2230004696

# %%
#Showing the used image.

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image
img = cv2.imread('output3.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %%
#Task 2.1:Negative transformation.
negative = 255 - gray

plt.imshow(negative, cmap='gray')
plt.title("Task 2.1 - Negative")
plt.axis("off")
plt.show()

# %%
#Task 2.2:Log transformation.
c = 255 / np.log(1 + np.max(gray))
log_transformed = c * np.log(1 + gray)
log_transformed = np.array(log_transformed, dtype=np.uint8)

plt.imshow(log_transformed, cmap='gray')
plt.title("Task 2.2 - Log Transformation")
plt.axis("off")
plt.show()

# %%
#Task 2.3:Power Law.
gamma = 0.5   # increases brightness & contrast

power_law = np.array(255 * (gray / 255) ** gamma, dtype='uint8')

plt.imshow(power_law, cmap='gray')
plt.title("Task 2.3 - Power Law (Gamma=0.5)")
plt.axis("off")
plt.show()
